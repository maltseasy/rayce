# %%
import sys, os
import pandas as pd
import numpy as np

from IPython.display import display

# %%
# Declare all variables as strings. Spaces must be replaced with '+', i.e., change 'John Smith' to 'John+Smith'.
# Define the lat, long of the location and the year
lat, lon, year = 33.2164, -97.1292, 2010
# You must request an NSRDB api key from the link above
api_key = 'oHJ9olM4GSKZjaLsf51aTqxd5kyaVTFL7t47pla1'
# Set the attributes to extract (e.g., dhi, ghi, etc.), separated by commas.
attributes = 'ghi,dhi,dni,wind_speed,air_temperature'
# Choose year of data
year = '2020'
# Set leap year to true or false. True will return leap day data if present, false will not.
leap_year = 'false'
# Set time interval in minutes, i.e., '30' is half hour intervals. Valid intervals are 30 & 60.
interval = '30'
# Specify Coordinated Universal Time (UTC), 'true' will use UTC, 'false' will use the local time zone of the data.
# NOTE: In order to use the NSRDB data in SAM, you must specify UTC as 'false'. SAM requires the data to be in the
# local time zone.
utc = 'false'
# Your full name, use '+' instead of spaces.
your_name = 'Aryan+Misra'
# Your reason for using the NSRDB.
reason_for_use = 'beta+testing'
# Your affiliation
your_affiliation = 'my+institution'
# Your email address
your_email = 'aryanmisra4@gmail.com'
# Please join our mailing list so we can keep you up-to-date on new developments.
mailing_list = 'true'

# Declare url string
url = 'https://developer.nrel.gov/api/nsrdb/v2/solar/psm3-download.csv?wkt=POINT({lon}%20{lat})&names={year}&leap_day={leap}&interval={interval}&utc={utc}&full_name={name}&email={email}&affiliation={affiliation}&mailing_list={mailing_list}&reason={reason}&api_key={api}&attributes={attr}'.format(year=year, lat=lat, lon=lon, leap=leap_year, interval=interval, utc=utc, name=your_name, email=your_email, mailing_list=mailing_list, affiliation=your_affiliation, reason=reason_for_use, api=api_key, attr=attributes)
# Return just the first 2 lines to get metadata:
info = pd.read_csv(url, nrows=1)
# See metadata for specified properties, e.g., timezone and elevation
timezone, elevation = info['Local Time Zone'], info['Elevation']

# %%
info
# Out:
#   Source  Location ID City State Country  Latitude  Longitude  Time Zone  \
# 0  NSRDB       693763    -     -       -     33.21     -97.14         -6
#
#    Elevation  Local Time Zone Clearsky DHI Units Clearsky DNI Units  \
# 0        203               -6               w/m2               w/m2
#
#   Clearsky GHI Units Dew Point Units DHI Units DNI Units GHI Units  \
# 0               w/m2               c      w/m2      w/m2      w/m2
#
#   Solar Zenith Angle Units Temperature Units Pressure Units  \
# 0                   Degree                 c           mbar
#
#   Relative Humidity Units Precipitable Water Units Wind Direction Units  \
# 0                       %                       cm              Degrees
#
#   Wind Speed Units  Cloud Type -15 Cloud Type 0    Cloud Type 1 Cloud Type 2  \
# 0              m/s             NaN        Clear  Probably Clear          Fog
#
#   Cloud Type 3        Cloud Type 4 Cloud Type 5 Cloud Type 6 Cloud Type 7  \
# ...

# %%
df = pd.read_csv('https://developer.nrel.gov/api/nsrdb/v2/solar/psm3-download.csv?wkt=POINT({lon}%20{lat})&names={year}&leap_day={leap}&interval={interval}&utc={utc}&full_name={name}&email={email}&affiliation={affiliation}&mailing_list={mailing_list}&reason={reason}&api_key={api}&attributes={attr}'.format(year=year, lat=lat, lon=lon, leap=leap_year, interval=interval, utc=utc, name=your_name, email=your_email, mailing_list=mailing_list, affiliation=your_affiliation, reason=reason_for_use, api=api_key, attr=attributes), skiprows=2)

# Set the time index in the pandas dataframe:
df = df.set_index(pd.date_range('1/1/{yr}'.format(yr=year), freq=interval+'Min', periods=525600/int(interval)))

# historical data (global horizontal irradiance), dhi (diffuse horizontal), dni (direct normal)
print('shape:', df.shape)
df.head(100)
# Out:
# shape: (17520, 10)
#                      Year  Month  Day  Hour  Minute  GHI  DHI  DNI  \
# 2020-01-01 00:00:00  2020      1    1     0       0    0    0    0
# 2020-01-01 00:30:00  2020      1    1     0      30    0    0    0
# 2020-01-01 01:00:00  2020      1    1     1       0    0    0    0
# 2020-01-01 01:30:00  2020      1    1     1      30    0    0    0
# 2020-01-01 02:00:00  2020      1    1     2       0    0    0    0
# 2020-01-01 02:30:00  2020      1    1     2      30    0    0    0
# 2020-01-01 03:00:00  2020      1    1     3       0    0    0    0
# 2020-01-01 03:30:00  2020      1    1     3      30    0    0    0
# 2020-01-01 04:00:00  2020      1    1     4       0    0    0    0
# 2020-01-01 04:30:00  2020      1    1     4      30    0    0    0
# 2020-01-01 05:00:00  2020      1    1     5       0    0    0    0
# 2020-01-01 05:30:00  2020      1    1     5      30    0    0    0
# 2020-01-01 06:00:00  2020      1    1     6       0    0    0    0
# ...

# %%
import requests
import json
import pprint

lat, lon = 32.2164, -96.1292
apikey = '972177cf8c6cdfe3dea736ac42d47346'
url = "https://api.openweathermap.org/data/2.5/forecast?lat={lat}&lon={lon}&units=metric&appid={apikey}".format(lat=lat, lon=lon, apikey=apikey)

response = requests.request("GET", url)

resp_dump = json.loads(response.text)
pprint.pprint(resp_dump)
#visibility, temp, cloud cover, precip chance
#5 days out, every 3 hours

#paid Solar Irradiance API gives data 15 days ahead
# Out:
# {'city': {'coord': {'lat': 32.2164, 'lon': -96.1292},
#           'country': 'US',
#           'id': 4737151,
#           'name': 'Tool',
#           'population': 2240,
#           'sunrise': 1684236380,
#           'sunset': 1684286138,
#           'timezone': -18000},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 100},
#            'dt': 1684281600,
#            'dt_txt': '2023-05-17 00:00:00',
#            'main': {'feels_like': 25.31,
#                     'grnd_level': 1001,
#                     'humidity': 69,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 24.96,
#                     'temp_kf': 2.11,
#                     'temp_max': 24.96,
#                     'temp_min': 22.85},
#            'pop': 0.19,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
# ...
